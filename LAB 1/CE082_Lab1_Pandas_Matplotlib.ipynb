# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/LAB 1/Data_for_Transformation.csv')

# %%
print(data.head())
plt.scatter(data["Age"], data['Salary'])
plt.show()
# Out:
#    Country  Age  Salary Purchased
# 0   France   44   72000        No
# 1    Spain   27   48000       Yes
# 2  Germany   30   54000        No
# 3    Spain   38   61000        No
# 4  Germany   40   68000       Yes

# %%
plt.hist(data['Salary'], bins = 10, color='blue')
plt.show()

# %%
fig_size = plt.figure(figsize=(8, 5))
plt.bar(data['Country'], data['Salary'], color='red')
plt.xlabel('Salaries')
plt.ylabel('Countries')
plt.title('Bar chart of Country vs Salary')
plt.show()
