# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
import matplotlib.pyplot as plt
import pandas as pd

# %%
# text analysis
text = """Discussing climate, sustainability, and preserving the natural world with President @EmmanuelMacron today in Paris. #BezosEarthFund #ClimatePledge"""

import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

remove_link = re.sub(f'https?:\/\/.*[\r\n]*', '', text)
remove_link = re.sub(r'#', '', remove_link)
print(remove_link)
# Out:
# Discussing climate, sustainability, and preserving the natural world with President @EmmanuelMacron today in Paris. BezosEarthFund ClimatePledge

# %%
print('\033[92m' + text)
print('\033[92m' + remove_link)
# Out:
# Discussing climate, sustainability, and preserving the natural world with President @EmmanuelMacron today in Paris. #BezosEarthFund #ClimatePledge
# Discussing climate, sustainability, and preserving the natural world with President @EmmanuelMacron today in Paris. BezosEarthFund ClimatePledge

# %%
from nltk.tokenize import sent_tokenize

text = """Hello Mr. Vasu, how you doing? whats up? The weather is great, and city is awesome. how you doing? The sky is pinkish-blue. """
nltk.download('punkt')
tokenized_text = sent_tokenize(text)
print(tokenized_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['Hello Mr. Vasu, how you doing?', 'whats up?', 'The weather is great, and city is awesome.', 'how you doing?', 'The sky is pinkish-blue.']

# %%
from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(text)

print(tokenized_word)
# Out:
# ['Hello', 'Mr.', 'Vasu', ',', 'how', 'you', 'doing', '?', 'whats', 'up', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'how', 'you', 'doing', '?', 'The', 'sky', 'is', 'pinkish-blue', '.']

# %%
# frequency distribution
from nltk.probability import FreqDist
fredist = FreqDist(tokenized_word)
fredist.most_common(4)

#plotting frequency distribution
import matplotlib.pyplot as plt
fredist.plot(30, cumulative = False, color = 'blue')
plt.show()

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'few', 'hasn', 'against', "you'll", "that'll", 'being', 'have', 'couldn', 've', 'yourselves', 'off', 'only', 'me', 'hadn', 'yourself', 'was', "wouldn't", 'ourselves', "it's", 'why', 'all', 'itself', 'it', 'here', "doesn't", 'mustn', 'them', 'what', 'o', 'into', 'just', 'ours', 'then', 'hers', "should've", 'a', "don't", 'm', "you'd", "you're", 'when', 'don', 'if', 'is', 'are', 'wouldn', 'they', 'whom', 's', 'won', 'not', 'i', 'does', 'been', 'of', 'ma', 'from', 'weren', 'doesn', 'isn', 'the', 'y', 'again', 'mightn', 'his', "hadn't", 'down', 'out', 'where', 'am', 'under', 'her', 'were', 'wasn', 'further', 'most', 'as', 'she', 'before', "weren't", "mustn't", 'himself', 'and', 'while', 'our', 'each', 'didn', 'that', 'with', 'aren', 'once', "aren't", 'than', 'who', 'between', 'has', 'should', 'which', 'too', 'by', 'both', 'for', 'haven', 'theirs', 'more', 'now', "won't", 'some', 'my', 'because', 'how', 'herself', 'same', 'its', 'myself', 'your', 'him', 're', 'shan', 'these', 'needn', "didn't", 'doing', 'or', 'own', 'be', 'an', "shan't", 'having', 'below', 'yours', "isn't", 'did', 'had', 'do', 'other', 'about', 'will', "mightn't", "shouldn't", "haven't", 'shouldn', 'any', "hasn't", 'up', 'we', 'above', 'in', "needn't", 'very', 'to', 'he', 'those', 'so', 'ain', 'you', 'their', "you've", 'but', 'at', "wasn't", 'no', 'can', "she's", 'nor', 'through', 'd', 'over', 'this', 'until', 'after', 'on', 'there', 't', 'll', "couldn't", 'during', 'themselves', 'such'}

# %%
filtered_sentence = []
for word in tokenized_word:
  if word not in stop_words:
    filtered_sentence.append(word)
print('Tokenized Sentence : \n', tokenized_word)
print('\nFiltered Sentence : \n', filtered_sentence)
# Out:
# Tokenized Sentence :
#  ['Hello', 'Mr.', 'Vasu', ',', 'how', 'you', 'doing', '?', 'whats', 'up', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'how', 'you', 'doing', '?', 'The', 'sky', 'is', 'pinkish-blue', '.']
#
# Filtered Sentence :
#  ['Hello', 'Mr.', 'Vasu', ',', '?', 'whats', '?', 'The', 'weather', 'great', ',', 'city', 'awesome', '.', '?', 'The', 'sky', 'pinkish-blue', '.']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()
stemmed_sentence = []
for word in filtered_sentence:
  stemmed_sentence.append(ps.stem(word))

print('Filtered Sentence : \n', filtered_sentence)
print('\nStemmed Sentence : \n', stemmed_sentence)
# Out:
# Filtered Sentence :
#  ['Hello', 'Mr.', 'Vasu', ',', '?', 'whats', '?', 'The', 'weather', 'great', ',', 'city', 'awesome', '.', '?', 'The', 'sky', 'pinkish-blue', '.']
#
# Stemmed Sentence :
#  ['hello', 'mr.', 'vasu', ',', '?', 'what', '?', 'the', 'weather', 'great', ',', 'citi', 'awesom', '.', '?', 'the', 'sky', 'pinkish-blu', '.']

# %%
# stemming and lemmatization

from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()

pSr = PorterStemmer()
word = 'crying'
print('Lemmatized Word  :  ', lemmatizer.lemmatize(word, 'v'))
print('Stemmed word  :  ', pSr.stem(word))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Lemmatized Word  :   cry
# Stemmed word  :   cri
