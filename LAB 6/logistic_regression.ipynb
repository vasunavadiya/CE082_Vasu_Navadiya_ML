# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importing libraries
import numpy as np 
import pandas as pd 
import io
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/LAB 6/BuyComputer.csv')

data.drop(columns=['User ID',],axis=1,inplace=True)
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
#Declare label as last column in the source file
label = data.iloc[:,-1].values

# %%
#Declaring X as all columns excluding last
X = data.iloc[:,:-1].values

# %%
# Splitting data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, label, test_size = 0.30, random_state = 82) #rollno 82

# %%
# Sacaling data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Variabes to calculate sigmoid function
y_pred = []
len_x = len(X_train[0])
w = []
b = 0.2
print(len_x)
# Out:
# 2

# %%
entries = len(X_train[:,0])
entries
# Out:
# 280

# %%
for weights in range(len_x):
    w.append(0)
w
# Out:
# [0, 0]

# %%
# Sigmoid function
def sigmoid(z):
  return (1 / (1 + np.exp(-z)))

# %%
def predict(inputs):
    z = np.dot(w,inputs) + b
    temp = sigmoid(z)
    return temp

# %%
#Loss function
def loss_func(y,a):
    J = -(y * np.log(a) + (1-y) * np.log(1-a))
    return J

# %%
dw = []
db = 0
J = 0
alpha = 0.1
for x in range(len_x):
    dw.append(0)

# %%
#Repeating the process 3000 times
for iterations in range(3000):
    for i in range(entries):
        localx = X_train[i]
        a = predict(localx)   
        dz = a - y_train[i]
        J += loss_func(y_train[i],a)

        for j in range(len_x):
            dw[j] = dw[j] + (localx[j] * dz)

        db += dz
    J = J / entries
    db = db / entries

    for x in range(len_x):
        dw[x] = dw[x] / entries

    for x in range(len_x):
        w[x] = w[x] - (alpha * dw[x])
    b = b - (alpha * db)         
    J=0

# %%
#Print weight
w
# Out:
# [2.0980897329711277, 1.1945226575450223]

# %%
#print bias
b
# Out:
# -1.2742991490448543

# %%
#predicting the label
for x in range(len(y_test)):
    y_pred.append(predict(X_test[x]))

# %%
#print actual and predicted values in a table
print("Actual\t\tPredicted")
for x in range(len(y_pred)):
    print(y_test[x] ,y_pred[x], sep="\t\t")
    if y_pred[x]>=0.5:
        y_pred[x]=1
    else:
        y_pred[x]=0
# Out:
# Actual		Predicted
# 0		0.022953582329738938
# 1		0.6923298409496962
# 1		0.7656528007583828
# 0		0.03364954515588429
# 1		0.20489622880779781
# 0		0.003252761636999481
# 0		0.26008700060192297
# 0		0.0034609019552717946
# 0		0.01280986868589277
# 1		0.6450198333704806
# 1		0.8393020670540778
# 0		0.3195792351333791
# 0		0.20939960861442064
# 1		0.4510013659244185
# 1		0.9625725614589863
# 1		0.6127260577476087
# 0		0.09155278124829713
# 0		0.04244439520378097
# 0		0.1635261554034148
# 1		0.5845811009182839
# 0		0.3938189344683242
# 0		0.011884791481460929
# 1		0.21400973791868277
# 0		0.05703147964086968
# 0		0.2037609389863366
# 1		0.5026282912390578
# 0		0.21869328797240115
# 1		0.8723849259278568
# 0		0.03718310593183518
# 0		0.22584718417619892
# 0		0.009104773061224335
# 0		0.11441687840697133
# 0		0.007995479463098816
# 1		0.2640790670343609
# 0		0.24066544299658496
# 0		0.46813987641682236
# 0		0.2777074675791282
# 1		0.8527786205790917
# 0		0.03064490629473567
# ...

# %%
# Calculating accuracy of prediction
count = 0
for x in range(len(y_pred)):
    if(y_pred[x] == y_test[x]):
        count += 1

print('Accuracy:',(count / (len(y_pred))) * 100)
# Out:
# Accuracy: 85.0

# %% [markdown]
# ## Using sklearn LogisticRegression model##

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state = 82) # roll no 82
#Fit
LR.fit(X_train,y_train)

#predicting the test label with LR. Predict always takes X as input
y_predict = LR.predict(X_test)

from sklearn.metrics import accuracy_score
print('Accuracy:', accuracy_score(y_predict,y_test))
# Out:
# Accuracy: 0.8416666666666667

# %% [markdown]
# **Exercise:**
#
# Try logistic regression on BuyComputer dataset and set Random state=Your_RollNumber (last 3 digit of ID, incase if you don't have ID)
